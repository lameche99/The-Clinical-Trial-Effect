# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# %%
cats = pd.read_csv('./ref/catalyst_with_sentiment_v1.csv')
sec = pd.read_csv('../sec_sentiment.csv')

# %%
cats.label.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='label'>

# %%
fig1 = px.histogram(sec, x='sentiment_score')
fig1.show()

# %%
fig2 = px.histogram(cats, x='sentiment_score')
fig2.show()
